# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4", streaming=True)

# %%
question = "Can you explain me GEN-AI ?"

# %%
response = llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# GEN-AI (Generative Artificial Intelligence) is a form of AI that focuses on training machine learning models to generate new, original content that convincingly resembles human output. This could be anything from text, photos, and music, to entire video games or even virtual realities. GEN-AI creates content based on patterns identified in training data, the larger and more diverse the data, the more complex and varied the outputs.
#
# For instance, using GEN-AI, an AI program can create a poem, compose a song, design a logo or generate a piece of artwork. One of the most known GEN-AI models, GPT-3, can generate incredibly human-like text based on a short input prompt. It can be used to write articles, answer questions, translate languages or create poems.
#
# It's important to note that while GEN-AI software can mimic human-like creativity and offer seemingly original content, the process is primarily data-driven and doesn't involve genuine understanding or conscious thought the way human creativity does.

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question = "Can you explain me GEN-AI ?"
response = llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# **Generative AI (Gen‑AI)** is a branch of artificial intelligence that focuses on creating new content—text, images, audio, video, code, or any other data type—rather than just classifying or predicting it.  Think of it as the “creative” side of AI: instead of answering “What is this?” it says “What could this be?”
#
# ---
#
# ## 1. Core Idea
#
# | Traditional AI | Generative AI |
# |----------------|---------------|
# | **Discriminative** models learn to *distinguish* between classes (e.g., spam vs. ham). | **Generative** models learn to *generate* realistic data that resembles the training set. |
# | Example: Logistic regression, SVM, standard classifiers. | Example: GPT‑4, DALL‑E, Stable Diffusion, WaveNet. |
# | Focus on *accuracy* of predictions. | Focus on *realism* and *coherence* of output. |
#
# ---
#
# ## 2. Key Technologies
#
# | Technology | How it works | Typical output |
# |------------|--------------|----------------|
# | **Transformer-based language models** (e.g., GPT‑4) | Self‑attention over large text corpora → learns probability of next token. | Text, chat, summarization, code generation. |
# | **Diffusion models** (e.g., Stable Diffusion) | Start with noise and iteratively denoise guided by a learned model → produces images. | Photorealistic images, artwork. |
# | **GANs (Generative Adversarial Networks)** | Two networks (generator & discriminator) play a game → generator learns to fool discriminator. | Early image synthesis, style transfer. |
# | **Variational Autoencoders (VAEs)** | Encode data into latent space, sample from that space, decode → generates new samples. | Music, simple images. |
# | **Autoregressive audio models** (e.g., WaveNet) | Predict next audio sample conditioned on previous samples. | Speech synthesis, music. |
# | **Multimodal foundation models** (e.g., CLIP + diffusion) | Jointly learn from text & images → can generate images from text prompts. | Text‑to‑image, captioning. |
#
# ---
#
# ## 3. How They’re Trained
#
# 1. **Data Collection**
#    Large, diverse datasets (books, websites, code repositories, image datasets, etc.).
# 2. **Pre‑training**
#    Unsupervised or self‑supervised objective (e.g., predicting the next word).
# 3. **Fine‑tuning**
#    Supervised or reinforcement learning on specific tasks (e.g., summarization, code completion).
# 4. **Inference**
#    Generate content by sampling from the learned probability distribution, guided by a prompt or seed.
#
# ---
#
# ## 4. Common Use Cases
#
# | Domain | Example Applications |
# |--------|----------------------|
# | **Text** | Chatbots, content creation, translation, summarization, creative writing. |
# | **Code** | GitHub Copilot, automated bug fixes, code generation from specs. |
# | **Images** | Graphic design, concept art, photo editing, style transfer. |
# | **Audio** | Voice assistants, music composition, speech synthesis. |
# | **Video** | Deepfake generation, video upscaling, automated editing. |
# | **Business** | Marketing copy, product descriptions, personalized recommendations. |
# | **Education** | Tutoring systems, automated grading, learning material generation. |
#
# ---
#
# ## 5. Why It Matters
#
# - **Speed & Scale**: Generates content in seconds that would take humans hours or days.
# - **Creativity Boost**: Provides new ideas, drafts, or prototypes that humans can refine.
# - **Accessibility**: Lowers barriers to entry for creative tasks (e.g., a non‑designer can produce a logo).
# - **Cost Efficiency**: Reduces labor for repetitive or large‑volume content creation.
#
# ---
#
# ## 6. Challenges & Risks
#
# | Issue | Description |
# |-------|-------------|
# | **Hallucinations** | Models may produce plausible‑but‑false information. |
# | **Bias & Fairness** | Training data can embed societal biases. |
# | **Copyright & Attribution** | Generated content might resemble copyrighted works. |
# | **Misuse** | Deepfakes, disinformation, automated phishing. |
# | **Compute & Energy** | Training large models requires massive GPU clusters and electricity. |
# | **Interpretability** | Understanding why a model generated a specific output is hard. |
#
# ---
#
# ## 7. The Future
#
# - **Multimodal Foundation Models** that seamlessly blend text, image, audio, and video.
# - **Smaller, Efficient Models** (distillation, pruning) that run on edge devices.
# - **Better Safety & Alignment** (reinforcement learning from human feedback, robust testing).
# - **Domain‑Specific Generative AI** (e.g., medical imaging, scientific simulation).
# - **Interactive Co‑Creation** where humans and AI collaborate in real time.
#
# ---
#
# ### Bottom Line
#
# Generative AI is the technology that lets computers *create* new, realistic content by learning patterns from massive datasets. It powers everything from chatbots and code assistants to AI‑generated art and music. While it opens up incredible possibilities, it also demands careful attention to ethics, safety, and responsible deployment.
