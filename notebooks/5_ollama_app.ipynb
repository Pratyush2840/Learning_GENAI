# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.1:8b")

# %%
res = llm.invoke("Hello, I am pratyush")
res.content
# Out:
# "Nice to meet you, Pratyush! How's your day going so far? Is there something I can help you with or would you like to chat about a particular topic?"
