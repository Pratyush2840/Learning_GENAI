# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Text Document Loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/speech.txt", encoding="utf-8")
texts = loader.load()
len(texts)

oneDoc = texts[0]
print(oneDoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# Our farmers are our pride.
# We honor their hard work and promise them:
# 	•	Better irrigation systems
# 	•	Access to modern farming technology
# 	•	Fair and timely MSP
# 	•	Improved cold storage and transport facilities
# 	•	Easier access to credit and crop insurance
#
# A nation that respects its farmers grows stronger every day.
#
# Friends,
# If we empower our youth, strengthen our education system, and support our farmers, no force can stop us from achieving prosperity.
#
# Let us walk this path together—towards growth, stability, and a brighter future.
#
# Thank you. Jai Hind.”

# %% [markdown]
# PDF Document Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/medical_report.pdf")
docs = loader.load()
len(docs)
# Out:
# 9

# %%
oneDoc = docs[0]
print(oneDoc.page_content)
# Out:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# Red Cell Distribution Width (RDW)  11.60 - 14.00 %11.90
# Total Leukocyte Count (TLC)  4.00 - 10.00 thou/mm37.33
# Differential Leucocyte Count (DLC)
#  40.00 - 80.00 Segmented Neutrophils %49.10
#  20.00 - 40.00 Lymphocytes %41.90
#  2.00 - 10.00 Monocytes %6.00
#  1.00 - 6.00 Eosinophils %2.50
#  <2.00 Basophils %0.50
# Absolute Leucocyte Count
#  2.00 - 7.00 Neutrophils thou/mm33.60
#  1.00 - 3.00 Lymphocytes thou/mm33.07
#  0.20 - 1.00 Monocytes thou/mm30.44
#  0.02 - 0.50 Eosinophils thou/mm30.18
# *474764803*
# .
# Page 1 of 9

# %% [markdown]
# CSV File Loader

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("../data/employee_records.csv")
docs = loader.load()
len(docs)
# Out:
# 30000

# %% [markdown]
# Web Page Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path="https://techsimplus.com/programs/1-Year-Placement-Oriented-Full-Stack-Developer-Program")
docs = loader.load()

# %%
docs[0].page_content
# Out:
# "TechSimPlus: 1-Year Placement-Oriented Full Stack Developer Program in BhopalInternshipVector 1.OEventsAbout UsCertificateConnect UsLoginHomeEventsAbout UsInstitute SolutionConnect UsLoginJoin Vector 1.OCopyright 2026 © TechSimPlus - The Symbol of Expertise.Designed by\xa0 Prateek Mishra1-Year Placement-Oriented Full Stack Developer ProgramLearn from Developers working at  Google, Apple, Samsung, Virtusa & More\nLearn the most in-demand technologies – Python, Django, React, Next Js, AWS Cloud, DevOps  and more.\n  \nNo Placement? We’ll Refund 100% of Your Fee!\nLearning ModeOffline ClassesProjects10+Duration1 Year\nStop dreaming about your first IT job — start training for it.\n\nWith focused learning, expert mentorship, and real-world practice, you’ll be ready to crack interviews and secure your dream IT job.\nDon’t wait for opportunity to find you — build it with us.\n\n\n\n90%\n\n                      Students Get Placed in 8 Months\n                    \n\n\n\n\n3-9 LPA\nAverage CTC You Will Get\n\n\n\n\n10+\nProject You will develop \n\n\n25,00050,000 1:1 Mock Interviews with Developers from Top Companies Build Real-World Projects. Solve 200+ DSA & Coding Interview Question Communication Skill Development Resume Building, LinkedIn & GitHub Profile Optimization 100% Refund If Not Placed (Terms Apply)Do You Have any Question ?About The program\n\n            Every student wants a good IT job, but many are not sure if they are\n            ready.  This program will help you feel confident and get\n            ready for your first job. \n\nA 12-month intensive, placement-driven program\n            designed to turn you into a job-ready full stack developer.\n          \n\n\n              Why Trust TechSimPlus Learnings?\n            \n\n              Our trainers work at top companies like \n              \n                Google, Apple, Samsung, Adobe, PwC, Deloitte, and Virtusa \n              \n              . They know exactly what companies want and teach you only what’s\n              important. No boring extras —\n              just the skills you really need to get hired.\n\n\n\n\n              How Do We Ensure You’re Ready?\n            \n\n              Along with training, we conduct\n              weekly mock interviews by experienced developers\n              to boost your confidence and communication.\n              Regular progress tests help you track your learning and stay on\n              course.\n            \n\n\n\n              What Makes Our Placement Guarantee Real?\n            \n\n              We’re connected with top companies ready to hire our students. And\n              if you don’t get placed, \n               We give you a 100% fee refund —\n              promised in writing when you join.\n            \nUpcoming BatchesWeekdaysOfflineBatch Start Date:Mon Jul 21 2025Batch Time:1. 4 PM to 8 PM (4 Hours)Fee: 25,000Apply NowWhat you'll learnThis curriculum designed by Industry expert for you to become a next industry expert. Here you will not only learn, you will implement your learnings in real time projects.\n\n\n\n\n\n\n\n\n\n            Basic Python and It's Fundamental Concept\n          \n\n4 Weeks\n\n\n\nDiscover the magic of Python by effortlessly installing it and setting up your development environment.\n After Installing Python we will be mastering the following fundamental Concepts. \n\nHello! World Program\nData Types\nVariables\nArray\nObjects\nControl Flow\nLoops\nFunctions and Modules\nFunctions and Modules\nFile handling\nLibraries\n\n\nFor Each topics, we will do hands on practice by solving many programs which will help you to build your logics and Increase your Imagination Power.\n\n\n\n\n\n\n\n\n\n\n\n            Data Structures and Algorithms with Python\n          \n\n8 Weeks\n\n\n\nBuild strong problem-solving skills by mastering essential Data Structures using Python. Understand how space and time complexity impact performance and optimization.\n\nBig-O Analysis\nTime &  ...
