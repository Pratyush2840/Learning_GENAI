# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Connect with Google Gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-flash-latest")

# %%
res = llm.invoke("What is GenAI ? Explain me in short ?")

# %%
print(res.content)
# Out:
# [{'type': 'text', 'text': '**GenAI (Generative Artificial Intelligence)** is a type of AI that can **create brand-new content**—like text, images, music, code, and videos—based on simple text instructions (prompts).\n\nUnlike traditional AI that only analyzes existing data (like predicting the weather or filtering spam), **GenAI creates something original** by learning patterns from massive amounts of information.\n\n### Popular Examples:\n* **Text:** ChatGPT, Claude (writes essays, answers questions, summarizes text)\n* **Images:** Midjourney, DALL-E (creates art and photos from descriptions)\n* **Code:** GitHub Copilot (writes computer programs)\n\n**In short:** It is an AI that acts like a creative assistant.', 'extras': {'signature': '...'}}]

# %% [markdown]
# Connect with OpenAI model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
res = llm.invoke("How to find largest number from a list in python ?")
print(res.content)
# Out:
# To find the largest number in a list in Python, you can use the built-in `max()` function, which is the simplest and most efficient way to accomplish this task. Here is an example:
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# largest_number = max(numbers)
# print("The largest number is:", largest_number)
# ```
#
# If you want to find the largest number manually (without using the `max()` function), you can iterate through the list and keep track of the largest number found so far:
#
# ```python
# numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# largest_number = numbers[0]
#
# for number in numbers:
#     if number > largest_number:
#         largest_number = number
#
# print("The largest number is:", largest_number)
# ```
#
# Both of these methods will give you the largest number from the list. The first method using `max()` is preferred for its simplicity and readability.

# %% [markdown]
# connect with anthropic model

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model="claude-opus-5")
response = llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# [{'signature': '...', 'thinking': '', 'type': 'thinking'}, {'text': "The capital of France is **Paris**. It's the country's largest city, located in the north-central part of France along the Seine River, and serves as its political, cultural, and economic center — home to landmarks like the Eiffel Tower, the Louvre, and Notre-Dame Cathedral.", 'type': 'text'}]

# %% [markdown]
# Static Prompts

# %%
prompts = [
    ("system", "You are a java developer."),    ### "system", "ai", , 'user'
    ("user", "How to sort the array.")
]

# %%
res = llm.invoke(prompts)
print(res.content)
# Out:
# [{'signature': '...', 'thinking': '', 'type': 'thinking'}, {'text': '# Sorting Arrays in Java\n\nThe short answer: **`java.util.Arrays.sort()`**. But the details depend on what you\'re sorting.\n\n## 1. Primitive arrays (int, double, char, …)\n\n```java\nint[] nums = {5, 2, 9, 1, 7};\nArrays.sort(nums);                 // [1, 2, 5, 7, 9]\n```\n\nUses a **dual-pivot quicksort** — O(n log n) average, no extra allocation, not stable (doesn\'t matter for primitives).\n\n**Sort only part of the array:**\n\n```java\nArrays.sort(nums, 1, 4);           // sorts indices [1, 4)\n```\n\n**Descending order for primitives?** There\'s no built-in comparator overload. Options:\n\n```java\n// Option A: sort ascending, then reverse\nArrays.sort(nums);\nfor (int i = 0, j = nums.length - 1; i < j; i++, j--) {\n    int t = nums[i]; nums[i] = nums[j]; nums[j] = t;\n}\n\n// Option B: box it (slower, but concise)\nInteger[] boxed = Arrays.stream(nums).boxed().toArray(Integer[]::new);\nArrays.sort(boxed, Comparator.reverseOrder());\n```\n\n## 2. Object arrays\n\n```java\nString[] names = {"Charlie", "alice", "Bob"};\nArrays.sort(names);                                    // natural order (Comparable)\nArrays.sort(names, String.CASE_INSENSITIVE_ORDER);     // custom comparator\nArrays.sort(names, Comparator.reverseOrder());         // descending\n```\n\nUses **TimSort** — O(n log n) worst case and **stable** (equal elements keep their relative order).\n\n## 3. Sorting your own objects\n\n```java\nrecord Person(String name, int age) {}\n\nPerson[] people = { new Person("Ann", 30), new Person("Bob", 25) };\n\n// By one field\nArrays.sort(people, Comparator.comparingInt(Person::age));\n\n// By multiple fields\nArrays.sort(people, Comparator.comparing(Person::name)\n                              .thenComparingInt(Person::age));\n\n// Descending, nulls last\nArrays.sort(people, Comparator.comparing(Person::name,\n                     Comparator.nullsLast(Comparator.reverseOrder())));\n```\n\nOr make the class implement `Comparable<T>` if there\'s an obvious "natural" order:\n\n```java\nclass Person implements Comparable<Person> {\n    public int compareTo(Person o) { return Integer.compare(this.age, o.age); }\n}\n```\n\n> ⚠️ Never write `(a, b) -> a.age - b.age` — it overflows. Use `Integer.compare()`.\n\n## 4. Large arrays: parallel sort\n\n```java\nArrays.parallelSort(bigArray);     // uses ForkJoinPool, worth it above ~8k elements\n```\n\n## 5. Streams (returns a new array, original untouched)\n\n```java\nint[] sorted = Arrays.stream(nums).sorted().toArray();\n\nString[] sortedNames = Arrays.stream(names)\n        .sorted(Comparator.comparing(String::length))\n        .toArray(String[]::new);\n```\n\n## 6. Lists (for completeness)\n\n```java\nList<String> list = new ArrayList<>(List.of("c", "a", "b"));\nCollections.sort(list);            // legacy style\nlist.sort(Comparator.naturalOrder());  // preferred, Java 8+\n```\n\n## 7. 2D arrays\n\n```java\nint[][] intervals = {{3,4},{1,2},{2,9}};\nArrays.sort(intervals, (a, b) -> Integer.compare(a[0], b[0]));\n// or: Arrays.sort(intervals, Comparator.comparingInt(a -> a[0]));\n```\n\n## Quick reference\n\n| Case | Call |\n|---|---|\n| `int[]` ascending | `Arrays.sort(a)` |\n| `int[]` descending | sort + reverse, or box |\n| `T[]` natural | `Arrays.sort(a)` |\n| `T[]` custom | `Arrays.sort(a, comparator)` |\n| Sub-range | `Arrays.sort(a, from, to)` |\n| Huge array | `Arrays.parallelSort(a)` |\n| Non-mutating | `Arrays.stream(a).sorted().toArray()` |\n\n---\n\nIf you\'re doing this as an **algorithms exercise** (implementing quicksort/mergesort yourself), or you have a specific array type/sorting rule in mind, tell me and I\'ll write that version.', 'type': 'text'}]
