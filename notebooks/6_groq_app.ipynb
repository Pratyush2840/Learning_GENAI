# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
openaiLLm = ChatOpenAI(model="gpt-5")

# %%
res = llm.invoke("Can you explain me GEN-AI ?")
print(res.content)
# Out:
# ### What is Generative AI?
#
# **Generative AI** (often shortened to “Gen‑AI”) refers to a class of artificial‑intelligence models that *create* new content instead of simply classifying or predicting it. Think of it as a digital “artist” that can write, draw, compose music, code, or even design products—all from scratch or by remixing existing data.
#
# ---
#
# ## Core Idea
#
# - **Input → Transformation → New Output**
#   The model receives a prompt (text, image, audio, etc.) and produces something that *could* have come from a human—an answer, a painting, a melody, a program, a 3‑D model, etc.
#
# - **Learning from Data**
#   It learns patterns, structures, and styles by being trained on massive datasets (books, websites, images, code, music). Once trained, it can generate novel combinations that respect those learned patterns.
#
# ---
#
# ## How It Works (High‑Level)
#
# | Step | What Happens | Key Tech |
# |------|--------------|----------|
# | 1. **Data Collection** | Gather huge corpora of the target modality (text, images, audio). | Web crawlers, public datasets (e.g., Common Crawl, ImageNet). |
# | 2. **Pre‑Training** | Train a neural network to predict missing parts or next tokens. | **Transformers** (attention‑based), **Diffusion Models**, **GANs**. |
# | 3. **Fine‑Tuning / Prompting** | Adapt the general model to specific tasks or styles. | Instruction‑tuned weights, prompt engineering, reinforcement learning from human feedback (RLHF). |
# | 4. **Generation** | Sample from the trained distribution to produce new content. | Beam search, nucleus sampling, diffusion sampling steps. |
#
# ### Why Transformers?
#
# - **Attention Mechanism** lets the model weigh every part of the input relative to every other part—essential for understanding long‑range dependencies.
# - **Scalability**: More layers, heads, and parameters → better language modeling.
# - **Versatility**: The same architecture works for text, images (Vision Transformers), audio, and even multimodal inputs.
#
# ### Diffusion Models (for images & audio)
#
# 1. **Forward Process**: Gradually add noise to an image until it becomes pure noise.
# 2. **Reverse Process**: Learn to denoise step‑by‑step, starting from random noise and ending with a coherent image.
#
# This iterative refinement produces high‑quality, diverse outputs and has become the backbone of models like **Stable Diffusion** and **Imagen**.
#
# ---
#
# ## Popular Generative AI Models
#
# | Modality | Example | Typical Use |
# |----------|---------|-------------|
# | **Text** | GPT‑4, Claude, Llama 2 | Chatbots, content creation, summarization, code generation |
# | **Images** | DALL‑E 3, Stable Diffusion, Midjourney | Graphic design, concept art, photo editing |
# | **Audio** | Jukebox, MusicLM, AudioLDM | Music composition, voice cloning, sound effects |
# | **Video** | VideoGPT, Stable Video Diffusion | Short video generation, animation, deepfake creation |
# | **Code** | Codex, GitHub Copilot | Auto‑completion, bug detection, refactoring |
# | **Multimodal** | Gemini, GPT‑4V, LLaVA | Text + image understanding, captioning, visual question answering |
#
# ---
#
# ## What Makes Gen‑AI Different From Traditional AI?
#
# | Feature | Traditional (Discriminative) | Generative |
# |---------|------------------------------|------------|
# | **Goal** | Predict a label or property | Produce new data |
# | **Training Objective** | Classification/regression | Likelihood maximization (next‑token prediction, denoising) |
# | **Output Space** | Discrete set of classes | Continuous space (any plausible content) |
# | **Evaluation** | Accuracy, F1, etc. | Perplexity, human judgment, visual fidelity |
#
# ---
#
# ## Common Applications
#
# | Domain | Gen‑AI Use‑Case | Value |
# |--------|-----------------|-------|
# | **Content Creation** | Auto‑write articles, generate marketing copy | Speed, scalability |
# | **Design** | Generate logos, UI mockups, 3‑D models | Rapid prototyping |
# | **Entertainment** | Compose music, script dialogue, create characters | New creative tools |
# | **Education** | Adaptive tutoring, generate practice problems | Personalized learning |
# | **Software Engineering** | Auto‑generate code, explain bugs | Developer productivity |
# | **Healthcare** | Generate synthetic medical data for research | Privacy‑preserving data augmentation |
#
# ---
#
# ## Strengths & Limitations
#
# | Strength | Limitation |
# |----------|------------|
# | **Creativity & Variety** | May produce nonsensical or irrelevant content (hallucinations). |
# | **Speed** | Generation can be slow for large models or high‑resolution outputs. |
# | **Generalization** | Trained on large corpora → can adapt to many tasks, but may inherit biases. |
# | **Explainability** | Black‑box nature; hard to trace why a particular output was produced. |
# | **Data Dependency** | Requires enormous, high‑quality datasets; privacy concerns. |
#
# ---
#
# ## Ethical & Safety Considerations
#
# - **Bias & Fairness**: Models can amplify societal biases present in training data.
# - **Misinformation**: Realistic text, images, or audio can be used to spread fake news or deepfakes.
# - **Copyright**: Generated content may inadvertently reproduce copyrighted material.
# - **Job Displacement**: Automation of creative tasks may affect certain professions.
# - **Misuse**: Generating disallowed content (violence, hate speech, etc.) requires robust moderation.
#
# Responsible deployment often involves:
# - **Content filters** (e.g., OpenAI’s Moderation API).
# - **User verification** (age, intent).
# - **Transparency** (disclosing AI‑generated nature).
# - **Human oversight** (reviewing outputs).
#
# ---
#
# ## A Quick Example
#
# **Prompt**: “Write a short story about a robot learning to paint.”
#
# 1. **Model**: GPT‑4 processes the prompt, retrieves patterns from stories about robots and art.
# 2. **Generation**: It produces a narrative with characters, conflict, and resolution.
# 3. **Output**: A coherent, human‑like short story that could have been written by an author.
#
# ---
#
# ## Future Directions
#
# - **Multimodal Fusion**: Seamless integration of text, image, audio, and 3‑D data in a single model.
# - **Few‑Shot Learning**: Generating high‑quality outputs from minimal user input.
# - **Efficient Models**: Distillation, pruning, and quantization to run Gen‑AI on edge devices.
# - **Explainable Generation**: Tracing the reasoning behind a creative decision.
# - **Regulation & Governance**: Developing standards for safe, fair, and accountable Gen‑AI use.
#
# ---
#
# ## TL;DR
#
# - **Generative AI** builds new content (text, images, audio, code, etc.) by learning patterns from vast datasets.
# - It relies on transformer architectures (for text) and diffusion or GAN models (for images/audio).
# - It powers tools like ChatGPT, DALL‑E, Stable Diffusion, and many others, enabling rapid content creation across industries.
# - While powerful, it brings challenges—hallucinations, bias, ethical misuse—that researchers and policymakers are actively addressing.
#
# Feel free to ask if you’d like deeper dives into any specific model, technique, or application!
