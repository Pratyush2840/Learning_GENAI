# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    {"role":"system", "content":"You are a JavaScript Developer ?"},
    {"role":"user", "content":"Difference b/w map and filter ?"},
]

# %%
res = llm.invoke(prompts)
print(res.content)
# Out:
# `map` and `filter` are both array methods in JavaScript that are used to manipulate arrays by applying a function to each element. However, they serve different purposes and have different behaviors:
#
# ### `map`
#
# - **Purpose**: Transforms each element in an array by applying a function to it and returns a new array containing the results.
# - **Return Value**: A new array with the same number of elements as the original array, but transformed according to the function you provide.
# - **Functionality**: Executes a provided function once for each array element and constructs a new array from the results.
# - **Use Case**: When you want to perform operations on each individual element of an array and get back a new array of the same size, possibly with modified items.
#
# **Example**:
# ```javascript
# const numbers = [1, 2, 3, 4, 5];
# const squaredNumbers = numbers.map(number => number * number);
# console.log(squaredNumbers); // Output: [1, 4, 9, 16, 25]
# ```
#
# ### `filter`
#
# - **Purpose**: Filters elements in an array based on a condition and returns a new array containing only those elements that satisfy the condition.
# - **Return Value**: A new array with potentially fewer elements than the original, depending on how many elements satisfy the filter condition.
# - **Functionality**: Executes a provided function once for each array element and constructs a new array with all elements that pass the test implemented by the provided function.
# - **Use Case**: When you need to extract a subset of elements from an array that meet certain criteria or condition.
#
# **Example**:
# ```javascript
# const numbers = [1, 2, 3, 4, 5];
# const evenNumbers = numbers.filter(number => number % 2 === 0);
# console.log(evenNumbers); // Output: [2, 4]
# ```
#
# In summary, use `map` when you want to transform all elements in an array, and use `filter` when you want to select a specific subset of elements.

# %%
prompts = [
    {"role":"system", "content":"You are a translator and translate input in Hindi ?"},
    {"role":"user", "content":"I love to play Cricket ?"},
]

# %%
res = llm.invoke(prompts)
print(res.content)
# Out:
# मैं क्रिकेट खेलना बहुत पसंद करता हूँ।

# %% [markdown]
# Prompt Templates - Dynamic Prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"You are a translator and translate input in {language} ?"},
    {"role":"user",  "content":"{query}"},
])

# %%
final_prompts = prompts.format_messages(language = "french ?", 
                                       query = "I love Python, and JavaScript ?")

# %%
res = llm.invoke(final_prompts)
print(res.content)
# Out:
# J'adore Python et JavaScript.

# %%
res = llm.invoke(prompts.invoke({"language":"Hindi", "query":"I love You ?"}))
res.content
# Out:
# 'मैं तुमसे प्यार करता हूँ / मैं तुमसे प्यार करती हूँ।'

# %% [markdown]
# chaining

# %%
#### My Self Chain Node

def transform_case(result:str):
    return result.upper()

# %%
out = StrOutputParser()

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"Hinglish", "query":"I love LangChain ?"})
print(res)
# Out:
# MAIN LANGCHAIN KO PASAND KARTA HOON.
